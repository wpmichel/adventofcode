# %%
from heapq import heappush, heappop
from collections import Counter

# %%
def read_input():
    with open("./input.txt", 'r') as f: 
        left, right = [], []
        for line in f.readlines(): 
            left_num, right_num = line.split("   ")
            heappush(left, int(left_num))
            heappush(right, int(right_num))
    return left, right

# %%
left, right = read_input()
diff = 0 
while left and right: 
    diff += abs(int(heappop(left)) - int(heappop(right)))
print(diff)
# Out:
# 1110981

# %%
left, right = read_input()
left, right = Counter(left), Counter(right)
sim_score = 0
for num, freq in left.items(): 
    if num in right: 
        sim_score += num*right[num]*freq
print(sim_score)
# Out:
# Counter({10032: 1, 10841: 1, 10588: 1, 10931: 1, 12043: 1, 10870: 1, 10590: 1, 12925: 1, 11205: 1, 14381: 1, 13105: 1, 11056: 1, 11277: 1, 12869: 1, 11119: 1, 13997: 1, 13222: 1, 11444: 1, 11212: 1, 21971: 1, 16417: 1, 13811: 1, 14513: 1, 12670: 1, 11727: 1, 16165: 1, 11513: 1, 14758: 1, 15332: 1, 11316: 1, 12200: 1, 15152: 1, 16005: 1, 14348: 1, 27500: 1, 14866: 1, 11720: 1, 12334: 1, 12501: 1, 28282: 1, 21988: 1, 16720: 1, 16564: 1, 23135: 1, 15191: 1, 15115: 1, 23800: 1, 15218: 1, 20554: 1, 15760: 1, 11814: 1, 17348: 1, 17488: 1, 12525: 1, 19258: 1, 15999: 1, 16484: 1, 19762: 1, 15496: 1, 12559: 1, 17412: 1, 20960: 1, 23529: 1, 17790: 1, 17674: 1, 19348: 1, 17492: 1, 21189: 1, 18532: 1, 32432: 1, 29960: 1, 23305: 1, 21071: 1, 12941: 1, 11937: 1, 22854: 1, 13462: 1, 18431: 1, 16169: 1, 32186: 1, 28937: 1, 25785: 1, 23096: 1, 39149: 1, 17379: 1, 19051: 1, 16851: 1, 25317: 1, 25729: 1, 34691: 1, 15692: 1, 17087: 1, 15654: 1, 25140: 1, 24872: 1, 34732: 1, 15283: 1, 32399: 1, 23253: 1,
# ...
